# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaaxo/Python_Lab_MumbaiUniversity/blob/main/EXP_2)_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **2. Advanced Data types and functions in Python:**
# *A.	Write a python program to perform following operations on an array:  Sum of all even elements, count the no. of elements divisible by 3, insert 2 elements at the end of the list, delete all the odd elements from the list.*

# %%
lol=[]

def gett():
  global lol

  x=int(input("Enter the size of array"))
  for v in range(0,x):
    c=int(input(f"Enter number{v+1}::"))
    lol.append(c)

def c1():
  print(f"the array you entered i{lol}")
  y=[i for x,i  in enumerate(lol) if i%2==0]
  print(f'the sum of all even number is {sum(y)}')

def c2():
  
  
  print(f"the array you entered i{lol}")
  y=[i for x,i  in enumerate(lol) if i%3==0]
  print(f"the number of elements divisible by 3 are {len(y)}")


def c3():

  global lol
  print(f"the array you entered i{lol}")
  b=2
  for v in range(0,b):
    c=int(input(f"Enter new number {v+1}"))
    lol.append(c)

  print(f'the new list is {lol}')  

def c4():

  global lol
  print(f"the array you entered i{lol}")
  y=[i for x,i  in enumerate(lol) if i%2==0]
  print(f"the new list after deleting the odd elements is \n{y}") 
    


def getc():
 print("Menu***************\n1.Enter Array\n2.count the no. of elements divisible by 3\n3.insert 2 elements at the end of the list\n4. delete all the odd elements from the list.\n5.Sum of all even elements\n6.EXIT")
 b=int(input("Enter your choice"))
 return b
c=getc()

while (c>0 and c<=5):
 if c==1:
   gett()
   c=getc()
 elif c==2:
   c2()
   c=getc()
 elif c==3:
   c3()
   c=getc()
 elif c==4:
   c4()
   c=getc()
 
 elif c==5:
   c1()
   c=getc()
# Out:
# Menu***************
# 1.Enter Array
# 2.count the no. of elements divisible by 3
# 3.insert 2 elements at the end of the list
# 4. delete all the odd elements from the list.
# 5.Sum of all even elements
# 6.EXIT
# Enter your choice1
# Enter the size of array4
# Enter number1::22
# Enter number2::21
# Enter number3::33
# Enter number4::34
# Menu***************
# 1.Enter Array
# 2.count the no. of elements divisible by 3
# 3.insert 2 elements at the end of the list
# 4. delete all the odd elements from the list.
# 5.Sum of all even elements
# 6.EXIT
# Enter your choice2
# the array you entered i[22, 21, 33, 34]
# the number of elements divisible by 3 are 2
# Menu***************
# 1.Enter Array
# 2.count the no. of elements divisible by 3
# 3.insert 2 elements at the end of the list
# 4. delete all the odd elements from the list.
# 5.Sum of all even elements
# 6.EXIT
# Enter your choice5
# the array you entered i[22, 21, 33, 34]
# the sum of all even number is 56
# Menu***************
# ...
